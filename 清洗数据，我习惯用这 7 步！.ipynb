# %% [markdown]
# https://mp.weixin.qq.com/s/0jx3cr0GhSabDZeG8Dj6CA

# %% [markdown]
# # 读入数据

# %%
import seaborn as sns
import numpy as np
titanic = sns.load_dataset("titanic")

# %%
data_raw = titanic.copy()
data_raw
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # 数据预览

# %%
data_raw.info()
data_raw.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %% [markdown]
# # 检查null值

# %%
data1 = data_raw.copy(deep=True)

data1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # 补全空值

# %%
data1['age'].fillna(data1['age'].median(), inplace = True)
data1['embarked'].fillna(data1['embarked'].mode()[0], inplace = True)
data1['embark_town'].fillna(data1['embark_town'].mode()[0], inplace = True)

data1.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# # 特征工程

# %% [markdown]
# ## 干掉 3 列

# %%
drop_column = ['deck','embark_town', 'who']
data1.drop(drop_column, axis=1, inplace = True)

# %% [markdown]
# ## 增加 3 列

# %%
data1['FamilySize'] = data1 ['sibsp'] + data1['parch'] + 1
data1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male alive  alone  FamilySize
# 0          True    no  False           2
# 1         False   yes  False           2
# 2         False   yes   True           1
# 3         False   yes  False           2
# 4          True    no   True           1
# ..          ...   ...    ...         ...
# 886        True    no   True           1
# 887       False   yes   True           1
# 888       False    no  False           4
# 889        True   yes   True           1
# 890        True    no   True           1
#
# [891 rows x 13 columns]

# %%
data1['IsAlone'] = np.where(data1['FamilySize'] > 1,0,1)
#data1['Title'] = data1['Name'].str.split(", ", expand=True)[1].str.split(".", expand=True)[0]
data1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male alive  alone  FamilySize  IsAlone
# 0          True    no  False           2        0
# 1         False   yes  False           2        0
# 2         False   yes   True           1        1
# 3         False   yes  False           2        0
# 4          True    no   True           1        1
# ..          ...   ...    ...         ...      ...
# 886        True    no   True           1        1
# 887       False   yes   True           1        1
# 888       False    no  False           4        0
# 889        True   yes   True           1        1
# 890        True    no   True           1        1
#
# [891 rows x 14 columns]

# %% [markdown]
# ## 分箱走起

# %%
import pandas as pd
data1['FareCut'] = pd.qcut(data1['fare'], 4)
data1['AgeCut'] = pd.cut(data1['age'].astype(int), 6)
data1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male alive  alone  FamilySize  IsAlone          FareCut  \
# 0          True    no  False           2        0   (-0.001, 7.91]
# 1         False   yes  False           2        0  (31.0, 512.329]
# 2         False   yes   True           1        1   (7.91, 14.454]
# 3         False   yes  False           2        0  (31.0, 512.329]
# 4          True    no   True           1        1   (7.91, 14.454]
# ..          ...   ...    ...         ...      ...              ...
# 886        True    no   True           1        1   (7.91, 14.454]
# 887       False   yes   True           1        1   (14.454, 31.0]
# 888       False    no  False           4        0   (14.454, 31.0]
# 889        True   yes   True           1        1   (14.454, 31.0]
# 890        True    no   True           1        1   (-0.001, 7.91]
#
#                AgeCut
# 0    (13.333, 26.667]
# 1      (26.667, 40.0]
# 2    (13.333, 26.667]
# 3      (26.667, 40.0]
# 4      (26.667, 40.0]
# ..                ...
# 886    (26.667, 40.0]
# 887  (13.333, 26.667]
# 888    (26.667, 40.0]
# 889  (13.333, 26.667]
# 890    (26.667, 40.0]
#
# [891 rows x 16 columns]

# %% [markdown]
# # 编码
# ## LabelEncoder 方法
# 使用 Sklearn 的 LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()
data1['Sex_Code'] = label.fit_transform(data1['sex'])
data1['Embarked_Code'] = label.fit_transform(data1['embarked'])
#data1['Title_Code'] = label.fit_transform(data1['Title'])
data1['AgeBin_Code'] = label.fit_transform(data1['AgeCut'])
data1['FareBin_Code'] = label.fit_transform(data1['FareCut'])
data1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male alive  alone  FamilySize  IsAlone          FareCut  \
# 0          True    no  False           2        0   (-0.001, 7.91]
# 1         False   yes  False           2        0  (31.0, 512.329]
# 2         False   yes   True           1        1   (7.91, 14.454]
# 3         False   yes  False           2        0  (31.0, 512.329]
# 4          True    no   True           1        1   (7.91, 14.454]
# ..          ...   ...    ...         ...      ...              ...
# 886        True    no   True           1        1   (7.91, 14.454]
# 887       False   yes   True           1        1   (14.454, 31.0]
# 888       False    no  False           4        0   (14.454, 31.0]
# 889        True   yes   True           1        1   (14.454, 31.0]
# 890        True    no   True           1        1   (-0.001, 7.91]
#
#                AgeCut  Sex_Code  Embarked_Code  AgeBin_Code  FareBin_Code
# 0    (13.333, 26.667]         1              2            1             0
# 1      (26.667, 40.0]         0              0            2             3
# 2    (13.333, 26.667]         0              2            1             1
# 3      (26.667, 40.0]         0              2            2             3
# 4      (26.667, 40.0]         1              2            2             1
# ..                ...       ...            ...          ...           ...
# 886    (26.667, 40.0]         1              2            2             1
# 887  (13.333, 26.667]         0              2            1             2
# 888    (26.667, 40.0]         0              2            2             2
# 889  (13.333, 26.667]         1              0            1             2
# 890    (26.667, 40.0]         1              1            2             0
#
# [891 rows x 20 columns]

# %% [markdown]
# ## get_dummies 方法
# get_dummies 将长 DataFrame 变为宽 DataFrame:
#
# 而 LabelEncoder 编码后，仅仅是把 Female 编码为 0， male 编码为 1

# %%
pd.get_dummies(data1['sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %% [markdown]
# # 再 check

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 20 columns):
# survived         891 non-null int64
# pclass           891 non-null int64
# sex              891 non-null object
# age              891 non-null float64
# sibsp            891 non-null int64
# parch            891 non-null int64
# fare             891 non-null float64
# embarked         891 non-null object
# class            891 non-null category
# adult_male       891 non-null bool
# alive            891 non-null object
# alone            891 non-null bool
# FamilySize       891 non-null int64
# IsAlone          891 non-null int32
# FareCut          891 non-null category
# AgeCut           891 non-null category
# Sex_Code         891 non-null int32
# Embarked_Code    891 non-null int32
# AgeBin_Code      891 non-null int32
# FareBin_Code     891 non-null int32
# dtypes: bool(2), category(3), float64(2), int32(5), int64(5), object(3)
# memory usage: 92.1+ KB
