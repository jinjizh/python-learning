# %% [markdown]
# # 参数优化及选择
# http://d0evi1.com/sklearn/cart/

# %% [markdown]
# #  GridSearchCV

# %%
from sklearn import tree

from sklearn.datasets import load_iris

from matplotlib import pyplot
import scipy as sp
import numpy as np
from matplotlib import pylab

from sklearn import datasets
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report

print(__doc__)

# Loading the Digits dataset
iris = load_iris()

X = iris.data 
y=iris.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.75, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {"criterion": ["gini", "entropy"],
              "min_samples_split": [2, 10, 20],
              "max_depth": [None, 2, 5, 10],
              "min_samples_leaf": [1, 5, 10],
              "max_leaf_nodes": [None, 5, 10, 20],
              }


clf = tree.DecisionTreeClassifier()

print("# Tuning hyper-parameters")
print()

# %%
# ?clf = GridSearchCV(clf, tuned_parameters, cv=10)
clf.fit(X_train, y_train)

print("Best parameters set found on development set:")
print()
print(clf.best_params_)
# Out:
# Best parameters set found on development set:
#
# {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
print("Grid scores on development set:")
print()

for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (+/-%0.03f) for %r"
          % (mean_score, scores.std() * 2, params))
# Out:
# Grid scores on development set:
#
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': None, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': None, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 5, 'min_samples_split': 20}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'min_samples_split': 20}

# %%
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()

print("use the best estimator to predict...")
# Out:
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# use the best estimator to predict...

# %%
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        38
#           1       0.88      1.00      0.94        37
#           2       1.00      0.87      0.93        38
#
# avg / total       0.96      0.96      0.96       113

# %% [markdown]
# # 使用RandomizedGrid的示例如下：

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

from sklearn import tree

from sklearn.datasets import load_iris

from matplotlib import pyplot
import scipy as sp
import numpy as np
from matplotlib import pylab

from scipy.stats import uniform as sp_rand
from scipy.stats import randint as sp_randint
from time import time

from sklearn import datasets
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report


# Loading the Digits dataset
iris = load_iris()

X = iris.data 
y=iris.target

print (X.shape)
print (y.shape)

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.75, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = {"criterion": ["gini", "entropy"],
              "min_samples_split": sp_randint(2, 20),
              "max_depth": sp_randint(2, 20),
              "min_samples_leaf": sp_randint(2, 20),
              "max_leaf_nodes": sp_randint(2,20),
              }

clf = tree.DecisionTreeClassifier()

print("# Tuning hyper-parameters")
print()

n_iter_search = 288 
clf = RandomizedSearchCV(clf, \
        param_distributions=tuned_parameters, \
        n_iter=n_iter_search, \
        cv=10)

start = time()
clf.fit(X_train, y_train)


print("RandomizedSearchCV took %.2f seconds for %d candidates"
        " parameter settings." % ((time() - start), n_iter_search))

print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (+/-%0.03f) for %r"
          % (mean_score, scores.std() * 2, params))
print()

print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()

print("use the best...")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
# (150, 4)
# (150,)
# # Tuning hyper-parameters
#
# RandomizedSearchCV took 4.82 seconds for 288 candidates parameter settings.
#
# {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 4, 'min_samples_leaf': 4, 'min_samples_split': 7}
#
# Grid scores on development set:
#
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 4, 'min_samples_leaf': 4, 'min_samples_split': 7}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 8, 'min_samples_leaf': 10, 'min_samples_split': 18}
# 0.676 (+/-0.050) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 2, 'min_samples_leaf': 4, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 9, 'min_samples_leaf': 6, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 3, 'min_samples_leaf': 3, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 16, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 18, 'min_samples_leaf': 2, 'min_samples_split': 4}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 11, 'max_leaf_nodes': 18, 'min_samples_leaf': 3, 'min_samples_split': 11}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 13, 'max_leaf_nodes': 13, 'min_samples_leaf': 17, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 12, 'min_samples_leaf': 7, 'min_samples_split': 6}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 4, 'min_samples_leaf': 9, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 17, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 7, 'min_samples_leaf': 17, 'min_samples_split': 13}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 5, 'min_samples_leaf': 4, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 3, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 7, 'min_samples_leaf': 8, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 18, 'min_samples_leaf': 2, 'min_samples_split': 7}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 14, 'max_leaf_nodes': 12, 'min_samples_leaf': 14, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 13, 'min_samples_leaf': 8, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 12, 'max_leaf_nodes': 11, 'min_samples_leaf': 6, 'min_samples_split': 9}
# 0.622 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 19, 'min_samples_leaf': 12, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 11, 'min_samples_leaf': 2, 'min_samples_split': 3}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 18, 'max_leaf_nodes': 16, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 15, 'max_leaf_nodes': 19, 'min_samples_leaf': 12, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 19, 'min_samples_leaf': 8, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 11, 'min_samples_leaf': 6, 'min_samples_split': 16}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 16, 'min_samples_leaf': 14, 'min_samples_split': 18}
# 0.324 (+/-0.050) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 14, 'min_samples_leaf': 19, 'min_samples_split': 7}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 16, 'max_leaf_nodes': 14, 'min_samples_leaf': 6, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 11, 'min_samples_leaf': 4, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 4, 'min_samples_leaf': 13, 'min_samples_split': 8}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 18, 'max_leaf_nodes': 12, 'min_samples_leaf': 9, 'min_samples_split': 7}
# 0.811 (+/-0.379) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 9, 'min_samples_leaf': 11, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 19, 'min_samples_leaf': 10, 'min_samples_split': 4}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 10, 'min_samples_leaf': 15, 'min_samples_split': 8}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 16, 'max_leaf_nodes': 18, 'min_samples_leaf': 14, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 17, 'min_samples_leaf': 6, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 19, 'min_samples_leaf': 9, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 5, 'min_samples_leaf': 15, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 16, 'min_samples_leaf': 9, 'min_samples_split': 9}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 4, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 13, 'min_samples_leaf': 14, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 11, 'min_samples_leaf': 10, 'min_samples_split': 17}
# 0.676 (+/-0.050) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 2, 'min_samples_leaf': 3, 'min_samples_split': 8}
# 0.324 (+/-0.050) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 14, 'min_samples_leaf': 19, 'min_samples_split': 19}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 11, 'max_leaf_nodes': 11, 'min_samples_leaf': 19, 'min_samples_split': 3}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 10, 'min_samples_leaf': 16, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 16, 'min_samples_leaf': 7, 'min_samples_split': 11}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 7, 'min_samples_leaf': 2, 'min_samples_split': 7}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 10, 'min_samples_leaf': 16, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 13, 'min_samples_leaf': 8, 'min_samples_split': 7}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 3, 'min_samples_leaf': 9, 'min_samples_split': 16}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 12, 'min_samples_leaf': 17, 'min_samples_split': 14}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 6, 'min_samples_leaf': 13, 'min_samples_split': 16}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 19, 'min_samples_leaf': 15, 'min_samples_split': 8}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 2, 'min_samples_leaf': 16, 'min_samples_split': 13}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 14, 'min_samples_leaf': 2, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 11, 'max_leaf_nodes': 16, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 11, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 8, 'min_samples_leaf': 3, 'min_samples_split': 12}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 9, 'min_samples_leaf': 18, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 9, 'min_samples_leaf': 13, 'min_samples_split': 19}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 10, 'min_samples_leaf': 12, 'min_samples_split': 4}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 17, 'max_leaf_nodes': 19, 'min_samples_leaf': 4, 'min_samples_split': 16}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 2, 'min_samples_leaf': 14, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 18, 'max_leaf_nodes': 13, 'min_samples_leaf': 2, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 8, 'min_samples_leaf': 8, 'min_samples_split': 18}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 9, 'min_samples_leaf': 16, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 15, 'min_samples_leaf': 4, 'min_samples_split': 19}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 5, 'min_samples_leaf': 11, 'min_samples_split': 12}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 12, 'min_samples_leaf': 11, 'min_samples_split': 7}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 19, 'min_samples_leaf': 7, 'min_samples_split': 7}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 18, 'min_samples_leaf': 2, 'min_samples_split': 10}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 7, 'min_samples_leaf': 14, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 18, 'min_samples_leaf': 4, 'min_samples_split': 4}
# 0.324 (+/-0.050) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 13, 'min_samples_leaf': 18, 'min_samples_split': 2}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 11, 'max_leaf_nodes': 15, 'min_samples_leaf': 18, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 14, 'max_leaf_nodes': 12, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 19, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.892 (+/-0.300) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 16, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 14, 'min_samples_split': 4}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 13, 'min_samples_leaf': 2, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 6, 'min_samples_leaf': 4, 'min_samples_split': 17}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 3, 'min_samples_leaf': 13, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 3, 'min_samples_leaf': 5, 'min_samples_split': 13}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 17, 'max_leaf_nodes': 6, 'min_samples_leaf': 17, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 8, 'min_samples_leaf': 10, 'min_samples_split': 8}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 5, 'min_samples_leaf': 9, 'min_samples_split': 12}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 19, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 7, 'min_samples_split': 9}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 8, 'min_samples_leaf': 15, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 8, 'min_samples_leaf': 10, 'min_samples_split': 17}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 16, 'max_leaf_nodes': 19, 'min_samples_leaf': 16, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 4, 'min_samples_leaf': 8, 'min_samples_split': 10}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 17, 'max_leaf_nodes': 6, 'min_samples_leaf': 14, 'min_samples_split': 14}
# 0.622 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 8, 'min_samples_leaf': 14, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 18, 'max_leaf_nodes': 7, 'min_samples_leaf': 9, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 5, 'min_samples_leaf': 5, 'min_samples_split': 5}
# 0.459 (+/-0.353) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 15, 'min_samples_leaf': 17, 'min_samples_split': 17}
# 0.459 (+/-0.353) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 12, 'min_samples_leaf': 17, 'min_samples_split': 2}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 4, 'min_samples_leaf': 16, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 3, 'min_samples_leaf': 8, 'min_samples_split': 18}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 2, 'min_samples_leaf': 14, 'min_samples_split': 12}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 12, 'min_samples_leaf': 14, 'min_samples_split': 8}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 3, 'min_samples_leaf': 13, 'min_samples_split': 4}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 8, 'min_samples_leaf': 16, 'min_samples_split': 13}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 12, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 15, 'min_samples_leaf': 11, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 9, 'min_samples_leaf': 8, 'min_samples_split': 8}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 7, 'max_leaf_nodes': 19, 'min_samples_leaf': 4, 'min_samples_split': 2}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 7, 'min_samples_leaf': 15, 'min_samples_split': 13}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 12, 'max_leaf_nodes': 18, 'min_samples_leaf': 6, 'min_samples_split': 16}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 15, 'min_samples_leaf': 16, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 18, 'max_leaf_nodes': 11, 'min_samples_leaf': 7, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 4, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 15, 'min_samples_leaf': 14, 'min_samples_split': 13}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 10, 'min_samples_leaf': 14, 'min_samples_split': 3}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 13, 'min_samples_leaf': 8, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 7, 'min_samples_leaf': 10, 'min_samples_split': 7}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 18, 'min_samples_leaf': 12, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 6, 'min_samples_leaf': 4, 'min_samples_split': 9}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 15, 'min_samples_leaf': 18, 'min_samples_split': 6}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 18, 'min_samples_leaf': 15, 'min_samples_split': 18}
# 0.514 (+/-0.300) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 17, 'min_samples_leaf': 16, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 7, 'max_leaf_nodes': 12, 'min_samples_leaf': 6, 'min_samples_split': 19}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 16, 'min_samples_leaf': 18, 'min_samples_split': 5}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 2, 'min_samples_leaf': 18, 'min_samples_split': 9}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 12, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 0.622 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 10, 'min_samples_leaf': 13, 'min_samples_split': 11}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 9, 'min_samples_leaf': 16, 'min_samples_split': 3}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 19, 'min_samples_leaf': 18, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 3, 'min_samples_leaf': 10, 'min_samples_split': 10}
# 0.459 (+/-0.353) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 17, 'min_samples_split': 13}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 12, 'min_samples_leaf': 14, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 3, 'min_samples_leaf': 8, 'min_samples_split': 9}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 11, 'min_samples_leaf': 16, 'min_samples_split': 3}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 12, 'min_samples_leaf': 10, 'min_samples_split': 13}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 6, 'min_samples_leaf': 12, 'min_samples_split': 10}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 6, 'min_samples_leaf': 17, 'min_samples_split': 3}
# 0.324 (+/-0.050) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 8, 'min_samples_leaf': 18, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 13, 'min_samples_leaf': 2, 'min_samples_split': 9}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 18, 'min_samples_leaf': 6, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 4, 'min_samples_leaf': 3, 'min_samples_split': 9}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 18, 'min_samples_leaf': 11, 'min_samples_split': 7}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 18, 'min_samples_leaf': 15, 'min_samples_split': 12}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 7, 'min_samples_leaf': 15, 'min_samples_split': 15}
# 0.838 (+/-0.327) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 12, 'min_samples_leaf': 11, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 6, 'min_samples_leaf': 6, 'min_samples_split': 17}
# 0.838 (+/-0.327) for {'criterion': 'entropy', 'max_depth': 16, 'max_leaf_nodes': 14, 'min_samples_leaf': 11, 'min_samples_split': 16}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 16, 'min_samples_leaf': 11, 'min_samples_split': 14}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 13, 'max_leaf_nodes': 4, 'min_samples_leaf': 19, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 4, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 12, 'min_samples_leaf': 7, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 7, 'max_leaf_nodes': 14, 'min_samples_leaf': 3, 'min_samples_split': 8}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 12, 'max_leaf_nodes': 17, 'min_samples_leaf': 16, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 12, 'min_samples_leaf': 5, 'min_samples_split': 8}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 13, 'min_samples_split': 6}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 9, 'min_samples_leaf': 5, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 11, 'min_samples_leaf': 13, 'min_samples_split': 3}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 12, 'min_samples_leaf': 13, 'min_samples_split': 6}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 3, 'min_samples_leaf': 3, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 6, 'min_samples_leaf': 14, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 6, 'min_samples_leaf': 9, 'min_samples_split': 11}
# 0.838 (+/-0.327) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 3, 'min_samples_leaf': 11, 'min_samples_split': 3}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 10, 'min_samples_leaf': 3, 'min_samples_split': 6}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 19, 'min_samples_leaf': 19, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 10, 'min_samples_leaf': 6, 'min_samples_split': 2}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 16, 'min_samples_leaf': 18, 'min_samples_split': 4}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 13, 'min_samples_leaf': 14, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 8, 'max_leaf_nodes': 15, 'min_samples_leaf': 15, 'min_samples_split': 14}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 9, 'min_samples_leaf': 15, 'min_samples_split': 8}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 3, 'min_samples_leaf': 5, 'min_samples_split': 13}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 13, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 16, 'min_samples_leaf': 14, 'min_samples_split': 3}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 13, 'max_leaf_nodes': 17, 'min_samples_leaf': 16, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 14, 'min_samples_leaf': 6, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 11, 'min_samples_leaf': 4, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 12, 'min_samples_leaf': 5, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 12, 'min_samples_leaf': 6, 'min_samples_split': 10}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 16, 'min_samples_leaf': 15, 'min_samples_split': 16}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 7, 'min_samples_leaf': 2, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 7, 'min_samples_leaf': 2, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 17, 'min_samples_leaf': 14, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 8, 'min_samples_leaf': 6, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 8, 'min_samples_leaf': 7, 'min_samples_split': 4}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 12, 'min_samples_leaf': 16, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 3, 'min_samples_leaf': 10, 'min_samples_split': 16}
# 0.676 (+/-0.050) for {'criterion': 'gini', 'max_depth': 15, 'max_leaf_nodes': 2, 'min_samples_leaf': 6, 'min_samples_split': 11}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 18, 'min_samples_leaf': 18, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 6, 'min_samples_leaf': 7, 'min_samples_split': 7}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 14, 'max_leaf_nodes': 4, 'min_samples_leaf': 17, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 12, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 8, 'min_samples_leaf': 2, 'min_samples_split': 6}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 13, 'min_samples_leaf': 6, 'min_samples_split': 7}
# 0.324 (+/-0.050) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 11, 'min_samples_leaf': 19, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 4, 'min_samples_leaf': 4, 'min_samples_split': 19}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 17, 'min_samples_leaf': 15, 'min_samples_split': 17}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 18, 'min_samples_leaf': 16, 'min_samples_split': 5}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 11, 'min_samples_leaf': 13, 'min_samples_split': 13}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 8, 'min_samples_leaf': 13, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 6, 'min_samples_leaf': 10, 'min_samples_split': 8}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 14, 'min_samples_leaf': 18, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 11, 'min_samples_leaf': 5, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 16, 'min_samples_leaf': 14, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 13, 'min_samples_leaf': 9, 'min_samples_split': 9}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 10, 'min_samples_leaf': 10, 'min_samples_split': 2}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 14, 'max_leaf_nodes': 10, 'min_samples_leaf': 19, 'min_samples_split': 12}
# 0.459 (+/-0.353) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 2, 'min_samples_leaf': 17, 'min_samples_split': 8}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 2, 'min_samples_split': 5}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 11, 'min_samples_leaf': 18, 'min_samples_split': 8}
# 0.676 (+/-0.050) for {'criterion': 'gini', 'max_depth': 17, 'max_leaf_nodes': 2, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 12, 'min_samples_leaf': 7, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 4, 'min_samples_leaf': 5, 'min_samples_split': 13}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 5, 'min_samples_leaf': 4, 'min_samples_split': 10}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 14, 'min_samples_split': 16}
# 0.622 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 17, 'min_samples_leaf': 14, 'min_samples_split': 2}
# 0.324 (+/-0.050) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 5, 'min_samples_leaf': 18, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 7, 'max_leaf_nodes': 18, 'min_samples_leaf': 9, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 7, 'max_leaf_nodes': 11, 'min_samples_leaf': 9, 'min_samples_split': 17}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 17, 'max_leaf_nodes': 12, 'min_samples_leaf': 9, 'min_samples_split': 6}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 13}
# 0.324 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 5, 'min_samples_leaf': 19, 'min_samples_split': 16}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 9, 'min_samples_leaf': 12, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 9, 'min_samples_leaf': 3, 'min_samples_split': 6}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 11, 'min_samples_leaf': 7, 'min_samples_split': 6}
# 0.811 (+/-0.379) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 16, 'min_samples_leaf': 11, 'min_samples_split': 11}
# 0.838 (+/-0.327) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 10, 'min_samples_leaf': 11, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 14, 'min_samples_leaf': 4, 'min_samples_split': 7}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 19, 'min_samples_leaf': 16, 'min_samples_split': 12}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 12, 'min_samples_leaf': 13, 'min_samples_split': 19}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 15, 'max_leaf_nodes': 6, 'min_samples_leaf': 16, 'min_samples_split': 12}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 16, 'max_leaf_nodes': 11, 'min_samples_leaf': 7, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 5, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 10, 'max_leaf_nodes': 12, 'min_samples_leaf': 8, 'min_samples_split': 8}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 17, 'min_samples_leaf': 9, 'min_samples_split': 15}
# 0.676 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 8, 'max_leaf_nodes': 2, 'min_samples_leaf': 2, 'min_samples_split': 7}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 13, 'min_samples_leaf': 10, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 16, 'min_samples_leaf': 3, 'min_samples_split': 3}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 14, 'min_samples_leaf': 13, 'min_samples_split': 18}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 7, 'max_leaf_nodes': 10, 'min_samples_leaf': 15, 'min_samples_split': 8}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 5, 'max_leaf_nodes': 18, 'min_samples_leaf': 12, 'min_samples_split': 7}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 10}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 5, 'min_samples_leaf': 12, 'min_samples_split': 19}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 6, 'max_leaf_nodes': 19, 'min_samples_leaf': 11, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 4, 'min_samples_leaf': 5, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 16, 'min_samples_leaf': 9, 'min_samples_split': 6}
# 0.541 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 10, 'min_samples_leaf': 16, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 9, 'min_samples_leaf': 14, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 6, 'min_samples_leaf': 5, 'min_samples_split': 4}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 14, 'max_leaf_nodes': 17, 'min_samples_leaf': 14, 'min_samples_split': 10}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 13, 'max_leaf_nodes': 4, 'min_samples_leaf': 5, 'min_samples_split': 7}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 2, 'min_samples_leaf': 12, 'min_samples_split': 14}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 17, 'max_leaf_nodes': 14, 'min_samples_leaf': 7, 'min_samples_split': 10}
# 0.541 (+/-0.269) for {'criterion': 'gini', 'max_depth': 3, 'max_leaf_nodes': 2, 'min_samples_leaf': 16, 'min_samples_split': 8}
# 0.811 (+/-0.379) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 14, 'min_samples_leaf': 11, 'min_samples_split': 6}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 18, 'min_samples_leaf': 17, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 8, 'min_samples_leaf': 2, 'min_samples_split': 8}
# 0.514 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 10, 'min_samples_leaf': 16, 'min_samples_split': 13}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 13, 'max_leaf_nodes': 19, 'min_samples_leaf': 13, 'min_samples_split': 9}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 4, 'min_samples_leaf': 14, 'min_samples_split': 10}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 16, 'min_samples_leaf': 13, 'min_samples_split': 13}
# 0.892 (+/-0.300) for {'criterion': 'entropy', 'max_depth': 10, 'max_leaf_nodes': 17, 'min_samples_leaf': 2, 'min_samples_split': 2}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 17, 'max_leaf_nodes': 9, 'min_samples_leaf': 10, 'min_samples_split': 9}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 19, 'max_leaf_nodes': 14, 'min_samples_leaf': 12, 'min_samples_split': 14}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 11, 'max_leaf_nodes': 4, 'min_samples_leaf': 14, 'min_samples_split': 7}
# 0.459 (+/-0.353) for {'criterion': 'entropy', 'max_depth': 11, 'max_leaf_nodes': 6, 'min_samples_leaf': 17, 'min_samples_split': 18}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 12, 'max_leaf_nodes': 12, 'min_samples_leaf': 5, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 16, 'max_leaf_nodes': 6, 'min_samples_leaf': 8, 'min_samples_split': 5}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 11, 'min_samples_leaf': 6, 'min_samples_split': 16}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 4, 'max_leaf_nodes': 4, 'min_samples_leaf': 7, 'min_samples_split': 19}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 3, 'max_leaf_nodes': 8, 'min_samples_leaf': 9, 'min_samples_split': 11}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 11, 'max_leaf_nodes': 7, 'min_samples_leaf': 12, 'min_samples_split': 17}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 17, 'min_samples_leaf': 15, 'min_samples_split': 14}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 19, 'max_leaf_nodes': 11, 'min_samples_leaf': 14, 'min_samples_split': 14}
# 0.622 (+/-0.133) for {'criterion': 'gini', 'max_depth': 9, 'max_leaf_nodes': 9, 'min_samples_leaf': 13, 'min_samples_split': 18}
# 0.514 (+/-0.300) for {'criterion': 'gini', 'max_depth': 18, 'max_leaf_nodes': 14, 'min_samples_leaf': 16, 'min_samples_split': 8}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 6, 'max_leaf_nodes': 7, 'min_samples_leaf': 12, 'min_samples_split': 7}
# 0.649 (+/-0.100) for {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 13, 'min_samples_leaf': 14, 'min_samples_split': 8}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 14, 'max_leaf_nodes': 12, 'min_samples_leaf': 10, 'min_samples_split': 3}
# 0.622 (+/-0.133) for {'criterion': 'entropy', 'max_depth': 2, 'max_leaf_nodes': 19, 'min_samples_leaf': 12, 'min_samples_split': 3}
# 0.676 (+/-0.050) for {'criterion': 'entropy', 'max_depth': 13, 'max_leaf_nodes': 2, 'min_samples_leaf': 2, 'min_samples_split': 15}
# 0.919 (+/-0.269) for {'criterion': 'entropy', 'max_depth': 15, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 5}
# 0.649 (+/-0.100) for {'criterion': 'entropy', 'max_depth': 9, 'max_leaf_nodes': 9, 'min_samples_leaf': 14, 'min_samples_split': 8}
# 0.838 (+/-0.327) for {'criterion': 'gini', 'max_depth': 5, 'max_leaf_nodes': 10, 'min_samples_leaf': 11, 'min_samples_split': 11}
# 0.919 (+/-0.269) for {'criterion': 'gini', 'max_depth': 2, 'max_leaf_nodes': 9, 'min_samples_leaf': 6, 'min_samples_split': 17}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
# use the best...
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        38
#           1       0.88      1.00      0.94        37
#           2       1.00      0.87      0.93        38
#
# avg / total       0.96      0.96      0.96       113
